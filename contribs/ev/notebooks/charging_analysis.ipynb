# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/home/isaacp/research/repos/EvMatsim/scenarios/utahev/output/ITERS/it.0/0.chargingStats.csv",
    sep=";",
)

# %%
df.head(100)
# Out:
#     chargerId  vehicleId  linkId waitStartTime waitEndTime waitDuration  \
# 0           1          1     371      00:00:00    01:04:08     00:00:00
# 1           2          1   16224      00:00:00    01:04:10     00:00:00
# 2           3          1     372      00:00:00    01:04:25     00:00:00
# 3           4          1      90      00:00:00    01:04:28     00:00:00
# 4           5          1   20800      00:00:00    01:04:32     00:00:00
# ..        ...        ...     ...           ...         ...          ...
# 56         57          1   17405      00:00:00    01:05:53     00:00:00
# 57         58          1   20802      00:00:00    01:05:57     00:00:00
# 58         59          1   20767      00:00:00    01:05:59     00:00:00
# 59         60          1   17404      00:00:00    01:06:03     00:00:00
# 60         61          1   13484      00:00:00    01:06:08     00:00:00
#
#    chargeStartTime chargeEndTime chargingDuration  energyTransmitted_kWh
# ...
